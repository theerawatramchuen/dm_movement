# %%
# Define cutoff date format 'mm/dd/yyyy'
cutoff_date = '11/19/2024'
# Define DM inventory Raw data CSV file name
dm_invent_csv = '/content/drive/MyDrive/dm_inv/DM Inventory Nov 13_24_120.XLS.csv'
# Define DM Movement Raw data CSV file name
dm_movement_csv = '/content/drive/MyDrive/dm_inv/movement Jan-Oct_24_120.csv'


#################################################################################
# !pip install pandasql -q
from google.colab import drive
import sys
import os
# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
# Add the directory containing your module to the Python path
sys.path.append('/content/drive/MyDrive/dm_inv')
# Now you can import your module
from dm_mvmnt_lib import dm_mvmnt_result
# Call the function
dm_mvmnt_result(cutoff_date, dm_invent_csv, dm_movement_csv)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File has been edited and saved as dm_invent.csv
# /content/drive/MyDrive/dm_inv/dm_mvmnt_lib.py:67: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(output_file,  usecols=[1,8,18,27], parse_dates=['Shlf.Date'], date_parser=custom_date_parser)
#      Material_1                   Shlf_Date     Batch    TTL
# 0        CG0002  2024-10-04 00:00:00.000000  11885709  147.5
# 1        CG0002  2025-03-12 00:00:00.000000  12274550  127.5
# 2        CG0002  2025-03-12 00:00:00.000000  12291480  130.0
# 3        CG0002  2025-03-26 00:00:00.000000  12291481  370.0
# 4        CZ0134  2025-03-27 00:00:00.000000  12291824   14.5
# ...         ...                         ...       ...    ...
# ...
