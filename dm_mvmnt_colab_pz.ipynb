# %%
# Define cutoff date format 'mm/dd/yyyy'
cutoff_date = "11/19/2024"
# Define DM inventory Raw data CSV file name
dm_invent_csv = "/content/drive/MyDrive/dm_inv/dm_inv/PZ_inven_Dec_11_2024.XLS.csv"
# Define DM Movement Raw data CSV file name
dm_movement_csv = "/content/drive/MyDrive/dm_inv/dm_inv/movement Jan-Oct_24_120.csv"


#################################################################################
# !pip install pandasql
from google.colab import drive
import sys
import os
# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
# Add the directory containing your module to the Python path
sys.path.append('/content/drive/MyDrive/dm_inv/dm_inv')
# Now you can import your module
from dm_mvmnt_pz_lib import dm_mvmnt_result
# Call the function
dm_mvmnt_result(cutoff_date, dm_invent_csv, dm_movement_csv)
# Out:
# ...
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File has been edited and saved as dm_invent.csv
#     Material_1   Shlf_Date     Batch   TTL
# 0       PZ0001  01/20/2023  11320863  50.0
# 1       PZ0001  06/18/2025  12054524   8.0
# 2       PZ0001  06/18/2025  12200885  10.0
# 3       PZ0001  09/20/2025  12281964  79.0
# 4       PZ0001  09/20/2025  12409577  23.0
# ..         ...         ...       ...   ...
# 678     PZ0212  09/20/2025  12334622   4.0
# 679     PZ0212  10/18/2025  12354786  10.0
# 680     PZ0212  10/18/2025  12363716  11.0
# 681     PZ0212  10/25/2025  12363717   1.0
# 682     PZ0212  10/25/2025  12363719   1.0
#
# [683 rows x 4 columns]
# File has been edited and saved as dm_movement.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130537 entries, 0 to 130536
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ...
